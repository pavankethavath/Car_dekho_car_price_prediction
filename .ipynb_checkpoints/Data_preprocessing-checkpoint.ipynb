# %% [markdown]
# # Car Dheko - Used Car Price Prediction

# %% [markdown]
# ### Extracting data from unstructured files of different cities to structured in one single CSV

# %%
# Importing required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import re
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
# checking the data of chennai cars sheet 
chennai_cars = pd.read_excel('chennai_cars.xlsx')
chennai_cars.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
# there ae 5 columns with unstructured data in all sheets so lets read the first row of each column to see structure

def print_column_data(column_name):
    print(column_name)
    print('  '*40)
    print(ast.literal_eval(chennai_cars[column_name][0]))
    print('  '*40)
    print('---'*40)

# List of column names to check
columns_to_check = ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']

# Loop through each column and print its first value
for column in columns_to_check:
    print_column_data(column)
# Out:
# new_car_detail
#
# {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '20,000', 'transmission': 'Automatic', 'ownerNo': 1, 'owner': '1st Owner', 'oem': 'Kia', 'model': 'Kia Sonet', 'modelYear': 2022, 'centralVariantId': 8654, 'variantName': 'Turbo DCT Anniversary Edition', 'price': '₹ 11.50 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}
#
# ------------------------------------------------------------------------------------------------------------------------
# new_car_overview
#
# {'heading': 'Car overview', 'top': [{'key': 'Registration Year', 'value': '2022', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/registrationYear.svg'}, {'key': 'Insurance Validity', 'value': 'Third Party insurance', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/insuranceValidity.svg'}, {'key': 'Fuel Type', 'value': 'Petrol', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/fuel.svg'}, {'key': 'Seats', 'value': '5 Seats', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/seats.svg'}, {'key': 'Kms Driven', 'value': '20,000 Kms', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/kmsDriven.svg'}, {'key': 'RTO', 'value': 'TN02', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/rto.svg'}, {'key': 'Ownership', 'value': 'First Owner', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/ownership.svg'}, {'key': 'Engine Displacement', 'value': '998 cc', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/engineDisplacement.svg'}, {'key': 'Transmission', 'value': 'Automatic', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/transmission.svg'}, {'key': 'Year of Manufacture', 'value': 2022, 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/yearManufacture.svg'}], 'bottomData': None}
#
# ------------------------------------------------------------------------------------------------------------------------
# new_car_feature
#
# {'heading': 'Features', 'top': [{'value': 'Power Steering'}, {'value': 'Power Windows Front'}, {'value': 'Air Conditioner'}, {'value': 'Heater'}, {'value': 'Adjustable Head Lights'}, {'value': 'Fog Lights Front'}, {'value': 'Anti Lock Braking System'}, {'value': 'Brake Assist'}, {'value': 'Radio'}], 'data': [{'heading': 'Comfort & Convenience', 'subHeading': 'Comfort', 'list': [{'value': 'Power Steering'}, {'value': 'Power Windows Front'}, {'value': 'Power Windows Rear'}, {'value': 'Low Fuel Warning Light'}, {'value': 'Accessory Power Outlet'}, {'value': 'Trunk Light'}, {'value': 'Rear Reading Lamp'}, {'value': 'Rear Seat Headrest'}, {'value': 'Rear Seat Centre Arm Rest'}, {'value': 'Cup Holders Rear'}, {'value': 'Multifunction Steering Wheel'}, {'value': 'Cruise Control'}, {'value': 'Rear ACVents'}, {'value': 'Smart Access Card Entry'}, {'value': 'Engine Start Stop Button'}, {'value': 'Steering Wheel Gearshift Paddles'}, {'value': 'Battery Saver'}, {'value': 'Drive Modes'}, {'value': 'Remote Engine Start Stop'}, {'value': 'Adjustable Headrest'}]}, {'heading': 'Interior', 'subHeading': 'Interior', 'list': [{'value': 'Air Conditioner'}, {'value': 'Heater'}, {'value': 'Adjustable Steering'}, {'value': 'Digital Odometer'}, {'value': 'Electronic Multi Tripmeter'}, {'value': 'Leather Seats'}, {'value': 'Fabric Upholstery'}, {'value': 'Leather Steering Wheel'}, {'value': 'Glove Compartment'}, {'value': 'Digital Clock'}, {'value': 'Driving Experience Control Eco'}, {'value': 'Height Adjustable Driver Seat'}, {'value': 'Leather Wrap Gear Shift Selector'}]}, {'heading': 'Exterior', 'subHeading': 'Exterior', 'list': [{'value': 'Adjustable Head Lights'}, {'value': 'Fog Lights Front'}, {'value': 'Power Adjustable Exterior Rear View Mirror'}, {'value': 'Electric Folding Rear View Mirror'}, {'value': 'Rear Window Defogger'}, {'value': 'Alloy Wheels'}, {'value': 'Integrated Antenna'}, {'value': 'Tinted Glass'}, {'value': 'Rear Spoiler'}, {'value': 'Sun Roof'}, {'value': 'Moon Roof'}, {'value': 'Outside Rear View Mirror Turn Indicators'}, {'value': 'Chrome Grille'}, {'value': 'Roof Rail'}, {'value': 'LEDDRLs'}, {'value': 'LEDHeadlights'}, {'value': 'LEDTaillights'}]}, {'heading': 'Safety', 'subHeading': 'Safety', 'list': [{'value': 'Anti Lock Braking System'}, {'value': 'Brake Assist'}, {'value': 'Centeral Locking'}, {'value': 'Power Door Locks'}, {'value': 'Child Safety Locks'}, {'value': 'Driver Air Bag'}, {'value': 'Passenger Air Bag'}, {'value': 'Side Air Bag Front'}, {'value': 'Day Night Rear View Mirror'}, {'value': 'Passenger Side Rear View Mirror'}, {'value': 'Rear Seat Belts'}, {'value': 'Seat Belt Warning'}, {'value': 'Vehicle Stability Control System'}, {'value': 'Traction Control'}, {'value': 'Adjustable Seats'}, {'value': 'Keyless Entry'}, {'value': 'Engine Check Warning'}, {'value': 'Crash Sensor'}, {'value': 'Automatic Head Lamps'}, {'value': 'Ebd'}, {'value': 'Follow Me Home Headlamps'}, {'value': 'Rear Camera'}, {'value': 'Anti Pinch Power Windows'}, {'value': 'Speed Sensing Auto Door Lock'}, {'value': 'Isofix Child Seat Mounts'}, {'value': 'Pretensioners And Force Limiter Seatbelts'}, {'value': 'Hill Assist'}, {'value': 'Impact Sensing Auto Door Lock'}, {'value': 'No Of Airbags'}, {'value': 'Eletronic Stability Control'}]}, {'heading': 'Entertainment & Communication', 'subHeading': 'Entertainment', 'list': [{'value': 'Radio'}, {'value': 'Speakers Front'}, {'value': 'Speakers Rear'}, {'value': 'Integrated2Din Audio'}, {'value': 'Bluetooth'}, {'value': 'Touch Screen'}, {'value': 'Number Of Speaker'}, {'value': 'Apple Car Play'}, {'value': 'Android Auto'}]}], 'commonIcon': 'https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg'}
#
# ------------------------------------------------------------------------------------------------------------------------
# new_car_specs
#
# {'heading': 'Specifications', 'top': [{'key': 'Engine', 'value': '998 CC'}, {'key': 'Max Power', 'value': '118.36bhp'}, {'key': 'Torque', 'value': '172nm'}, {'key': 'Wheel Size', 'value': '16'}, {'key': 'Seats', 'value': '5'}], 'data': [{'heading': 'Engine and Transmission', 'subHeading': 'Engine', 'list': [{'key': 'Color', 'value': 'Black'}, {'key': 'Engine Type', 'value': 'Smartstream G1.0 T - GDi'}, {'key': 'Displacement', 'value': '998'}, {'key': 'Max Power', 'value': '118.36bhp@6000rpm'}, {'key': 'Max Torque', 'value': '172nm@1500-4000rpm'}, {'key': 'No of Cylinder', 'value': 3}, {'key': 'Values per Cylinder', 'value': 4}, {'key': 'Fuel Suppy System', 'value': 'GDi'}, {'key': 'Turbo Charger', 'value': 'Yes'}]}, {'heading': 'Dimensions & Capacity', 'subHeading': 'Dimensions', 'list': [{'key': 'Length', 'value': '3995mm'}, {'key': 'Width', 'value': '1790'}, {'key': 'Height', 'value': '1642'}, {'key': 'Wheel Base', 'value': '2500'}, {'key': 'Kerb Weight', 'value': '1465'}]}, {'heading': 'Miscellaneous', 'subHeading': 'Miscellaneous', 'list': [{'key': 'Gear Box', 'value': '7-Speed DCT'}, {'key': 'Drive Type', 'value': 'FWD'}, {'key': 'Seating Capacity', 'value': '5'}, {'key': 'Steering Type', 'value': 'Electric'}, {'key': 'Front Brake Type', 'value': 'Disc'}, {'key': 'Rear Brake Type', 'value': 'Drum'}, {'key': 'Tyre Type', 'value': 'Tubeless, Radial'}, {'key': 'Alloy Wheel Size', 'value': '16'}, {'key': 'No Door Numbers', 'value': '5'}, {'key': 'Cargo Volumn', 'value': '392'}]}], 'commonIcon': ''}
#
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Extracting Data in Structured Format

# %%
# writing functons to load all data from the files of different cities and extracting feature from each row
# making a combined sheet

# %%
def extract_car_data(file_path, city_name):
    # Loading the Excel file
    data = pd.read_excel(file_path)
    
    # Utility function to safely evaluate strings to dictionaries
    def safe_eval(detail):
        try:
            return ast.literal_eval(detail)
        except (ValueError, SyntaxError):
            return {}

    # Function to extract fields from 'new_car_detail'
    def extract_car_details(detail):
        car_detail = safe_eval(detail)
        return pd.Series({
            'ignition_type': car_detail.get('it'),
            'fuel_type': car_detail.get('ft'),
            'body_type': car_detail.get('bt'),
            'kilometers_driven': car_detail.get('km'),
            'transmission': car_detail.get('transmission'),
            'owner_no': car_detail.get('ownerNo'),
            'owner': car_detail.get('owner'),
            'manufacturer': car_detail.get('oem'),
            'model': car_detail.get('model'),
            'model_year': car_detail.get('modelYear'),
            'central_variant_id': car_detail.get('centralVariantId'),
            'variant_name': car_detail.get('variantName'),
            'price': car_detail.get('price'),
            'priceActual': car_detail.get('priceActual'),
            'priceSaving': car_detail.get('priceSaving'),
            'priceFixedText': car_detail.get('priceFixedText'),
            'trendingText': car_detail.get('trendingText'),
            'heading': car_detail.get('heading'),
            'description': car_detail.get('desc')
        })

    # Function to extract fields from 'new_car_overview'
    def extract_car_overview(overview):
        overview_data = safe_eval(overview)
        overview_dict = {item['key']: item['value'] for item in overview_data.get('top', [])}
        return pd.Series({
            'registration_year': overview_dict.get('Registration Year'),
            'insurance': overview_dict.get('Insurance Validity'),
            'Fuel_type': overview_dict.get('Fuel Type'),
            'kms_driven': overview_dict.get('Kms Driven'),
            'rto': overview_dict.get('RTO'),
            'ownership': overview_dict.get('Ownership'),
            'engine_displacement': overview_dict.get('Engine Displacement'),
            'Transmission': overview_dict.get('Transmission'),
            'year_of_manufacture': overview_dict.get('Year of Manufacture')
        })

    # Function to extract features from 'new_car_feature'
    def extract_car_features(features):
        features_data = safe_eval(features)
        top_features = [item.get('value') for item in features_data.get('top', [])]

        feature_categories = {}
        for category in features_data.get('data', []):
            heading = category.get('heading')
            feature_list = ', '.join(item.get('value') for item in category.get('list', []))
            feature_categories[heading] = feature_list
        
        return pd.Series({
            'top_eatures': ', '.join(top_features),
            'comfort_features': feature_categories.get('Comfort & Convenience', ''),
            'interior_features': feature_categories.get('Interior', ''),
            'exterior_features': feature_categories.get('Exterior', ''),
            'safety_features': feature_categories.get('Safety', ''),
            'entertainment_features': feature_categories.get('Entertainment & Communication', '')
        })

    # Function to extract specifications from 'new_car_specs'
    def extract_car_specs(specs):
        specs_data = safe_eval(specs)
        specs_dict = {item['key']: item['value'] for item in specs_data.get('top', [])}

        detailed_specs = {}
        for category in specs_data.get('data', []):
            for item in category.get('list', []):
                detailed_specs[item['key']] = item['value']

        return pd.Series({
            'engine': specs_dict.get('Engine'),
            'max_power': specs_dict.get('Max Power'),
            'torque': specs_dict.get('Torque'),
            'wheel_size': specs_dict.get('Wheel Size'),
            'seats': specs_dict.get('Seats'),
            'color': detailed_specs.get('Color'),
            'engine_type': detailed_specs.get('Engine Type'),
            'displacement': detailed_specs.get('Displacement'),
            'engine_max_power': detailed_specs.get('Max Power'),
            'engine_max_torque': detailed_specs.get('Max Torque'),
            'no_of_cylinders': detailed_specs.get('No of Cylinder'),
            'values_per_cylinder': detailed_specs.get('Values per Cylinder'),
            'fuel_suppy_system': detailed_specs.get('Fuel Suppy System'),
            'turbo_charger': detailed_specs.get('Turbo Charger'),
            'length': detailed_specs.get('Length'),
            'width': detailed_specs.get('Width'),
            'height': detailed_specs.get('Height'),
            'wheel_base': detailed_specs.get('Wheel Base'),
            'kerb_weight': detailed_specs.get('Kerb Weight'),
            'gear_box': detailed_specs.get('Gear Box'),
            'drive_type': detailed_specs.get('Drive Type'),
            'steering_type': detailed_specs.get('Steering Type'),
            'seating_capacity': detailed_specs.get('Seating Capacity'),
            'front_brake_type': detailed_specs.get('Front Brake Type'),
            'rear_brake_type': detailed_specs.get('Rear Brake Type'),
            'tyre_type': detailed_specs.get('Tyre Type'),
            'alloy_wheel_size': detailed_specs.get('Alloy Wheel Size'),
            'no_of_doors': detailed_specs.get('No Door Numbers'),
            'cargo_volumn': detailed_specs.get('Cargo Volumn')
        })

    # Apply the functions to the relevant columns
    car_details_df = data['new_car_detail'].apply(extract_car_details)
    car_overview_df = data['new_car_overview'].apply(extract_car_overview)
    car_features_df = data['new_car_feature'].apply(extract_car_features)
    car_specs_df = data['new_car_specs'].apply(extract_car_specs)

    # Concatenate all the extracted DataFrames
    combined_df = pd.concat([car_details_df, car_overview_df, car_features_df, car_specs_df], axis=1)
    
    # Add a column for the city name
    combined_df['city'] = city_name
    
    return combined_df

# %%
# List of city Excel files and corresponding city names
city_files = [
    ('chennai_cars.xlsx', 'Chennai'),
    ('hyderabad_cars.xlsx', 'Hyderabad'),
    ('bangalore_cars.xlsx', 'Bangalore'),
    ('delhi_cars.xlsx', 'delhi'),
    ('jaipur_cars.xlsx', 'jaipur'),
    ('kolkata_cars.xlsx', 'kolkata')
]

# Initialize an empty DataFrame to hold the combined data
final_df = pd.DataFrame()

# Loop through each city file and extract data
for file_path, city_name in city_files:
    city_data = extract_car_data(file_path, city_name)
    
    # Append the city's data to the final DataFrame
    final_df = pd.concat([final_df, city_data], ignore_index=True)

# Display the final combined DataFrame
final_df.head()
# Out:
#    ignition_type fuel_type  body_type kilometers_driven transmission  \
# 0              0    Petrol        SUV            20,000    Automatic
# 1              0    Petrol   Minivans            20,687       Manual
# 2              0    Petrol        SUV            30,000       Manual
# 3              0    Petrol  Hatchback            59,247       Manual
# 4              0    Petrol  Hatchback            50,000       Manual
#
#    owner_no      owner manufacturer           model  model_year  ...  \
# 0         1  1st Owner          Kia       Kia Sonet        2022  ...
# 1         1  1st Owner       Maruti     Maruti Eeco        2015  ...
# 2         1  1st Owner       Nissan  Nissan Magnite        2021  ...
# 3         1  1st Owner      Hyundai     Hyundai i10        2015  ...
# 4         1  1st Owner        Honda      Honda Jazz        2015  ...
#
#    drive_type steering_type seating_capacity front_brake_type rear_brake_type  \
# 0         FWD      Electric                5             Disc            Drum
# 1         RWD        Manual                7  Ventilated Disc            Drum
# 2        None    Electronic                5             Disc            Drum
# 3         FWD         Power                5  Ventilated Disc            Drum
# 4         FWD         Power                5             Disc            Drum
#
#           tyre_type alloy_wheel_size no_of_doors cargo_volumn     city
# 0  Tubeless, Radial               16           5          392  Chennai
# 1    Tubeless Tyres             None           5   540-liters  Chennai
# 2   Tubeless,Radial               16           5          336  Chennai
# 3          Tubeless             None           5   225-litres  Chennai
# 4   Tubeless,Radial               15           5   354-litres  Chennai
#
# [5 rows x 64 columns]

# %%
# checking the rows and columns of the combined data

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
final_df.head(5)
# Out:
#    ignition_type fuel_type  body_type kilometers_driven transmission  \
# 0              0    Petrol        SUV            20,000    Automatic
# 1              0    Petrol   Minivans            20,687       Manual
# 2              0    Petrol        SUV            30,000       Manual
# 3              0    Petrol  Hatchback            59,247       Manual
# 4              0    Petrol  Hatchback            50,000       Manual
#
#    owner_no      owner manufacturer           model  model_year  \
# 0         1  1st Owner          Kia       Kia Sonet        2022
# 1         1  1st Owner       Maruti     Maruti Eeco        2015
# 2         1  1st Owner       Nissan  Nissan Magnite        2021
# 3         1  1st Owner      Hyundai     Hyundai i10        2015
# 4         1  1st Owner        Honda      Honda Jazz        2015
#
#    central_variant_id                   variant_name         price  \
# 0                8654  Turbo DCT Anniversary Edition  ₹ 11.50 Lakh
# 1                4025         7 Seater Standard BSIV   ₹ 4.15 Lakh
# 2                8135          Turbo XV Premium BSVI   ₹ 7.50 Lakh
# 3                1579                    Sportz 1.1L   ₹ 3.98 Lakh
# 4                1341                  1.2 VX i VTEC   ₹ 5.50 Lakh
#
#   priceActual priceSaving priceFixedText  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
#
#                                         trendingText heading description  \
# 0  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 2  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 3  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 4  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
#
#   registration_year              insurance Fuel_type  kms_driven   rto  \
# 0              2022  Third Party insurance    Petrol  20,000 Kms  TN02
# 1          Feb 2015          Comprehensive    Petrol  20,687 Kms  TN04
# 2              2021  Third Party insurance    Petrol  30,000 Kms  TN22
# 3          May 2015          Comprehensive    Petrol  59,247 Kms  TN11
# 4              2015  Third Party insurance    Petrol  50,000 Kms  KA03
#
#      ownership engine_displacement Transmission  year_of_manufacture  \
# 0  First Owner              998 cc    Automatic               2022.0
# 1  First Owner             1196 cc       Manual               2015.0
# 2  First Owner              999 cc       Manual               2021.0
# 3  First Owner             1086 cc       Manual               2015.0
# 4  First Owner             1199 cc       Manual               2015.0
#
#                                          top_eatures  \
# 0  Power Steering, Power Windows Front, Air Condi...
# 1  Low Fuel Warning Light, Accessory Power Outlet...
# 2  Power Steering, Power Windows Front, Air Condi...
# 3  Power Steering, Power Windows Front, Air Condi...
# 4  Power Steering, Power Windows Front, Air Condi...
#
#                                     comfort_features  \
# 0  Power Steering, Power Windows Front, Power Win...
# 1  Low Fuel Warning Light, Accessory Power Outlet...
# 2  Power Steering, Power Windows Front, Power Win...
# 3  Power Steering, Power Windows Front, Power Win...
# 4  Power Steering, Power Windows Front, Power Win...
#
#                                    interior_features  \
# 0  Air Conditioner, Heater, Adjustable Steering, ...
# 1  Heater, Digital Odometer, Electronic Multi Tri...
# 2  Air Conditioner, Heater, Adjustable Steering, ...
# 3  Air Conditioner, Heater, Adjustable Steering, ...
# 4  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                    exterior_features  \
# 0  Adjustable Head Lights, Fog Lights Front, Powe...
# 1  Adjustable Head Lights, Manually Adjustable Ex...
# 2  Adjustable Head Lights, Fog Lights Front, Powe...
# 3  Adjustable Head Lights, Fog Lights Front, Manu...
# 4  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                      safety_features  \
# 0  Anti Lock Braking System, Brake Assist, Center...
# 1  Anti Lock Braking System, Child Safety Locks, ...
# 2  Anti Lock Braking System, Brake Assist, Center...
# 3  Centeral Locking, Power Door Locks, Child Safe...
# 4  Anti Lock Braking System, Centeral Locking, Po...
#
#                               entertainment_features   engine  max_power  \
# 0  Radio, Speakers Front, Speakers Rear, Integrat...   998 CC  118.36bhp
# 1                                                     1196 CC      73bhp
# 2  Radio, Speakers Front, Speakers Rear, Integrat...   999 CC   98.63bhp
# 3  Cd Player, Radio, Speakers Front, Speakers Rea...  1086 CC   68.05bhp
# 4  Cd Player, Dvd Player, Radio, Speakers Front, ...  1199 CC    88.7bhp
#
#     torque wheel_size seats   color               engine_type displacement  \
# 0    172nm         16     5   Black  Smartstream G1.0 T - GDi          998
# 1    101Nm       None     7    Grey            In-Line Engine         1196
# 2    160Nm         16     5  Others     HRA0 1.0 TURBO PETROL          999
# 3  99.04Nm       None     5  Silver              IRDE2 Engine         1086
# 4    110Nm         15     5  Others      i-VTEC Petrol Engine         1199
#
#     engine_max_power   engine_max_torque  no_of_cylinders  \
# 0  118.36bhp@6000rpm  172nm@1500-4000rpm              3.0
# 1      73bhp@6000rpm       101Nm@3000rpm              4.0
# 2   98.63bhp@5000rpm  160Nm@2800-3600rpm              3.0
# 3   68.05bhp@5500rpm     99.04Nm@4500rpm              4.0
# 4    88.7bhp@6000rpm       110Nm@4800rpm              4.0
#
#    values_per_cylinder fuel_suppy_system turbo_charger  length   width  \
# 0                  4.0               GDi           Yes  3995mm    1790
# 1                  4.0              MPFi            No  3675mm  1475mm
# 2                  4.0              MPFi           Yes  3994mm    1758
# 3                  3.0              MPFI            No  3585mm  1595mm
# 4                  4.0          PGM - Fi            No  3955mm  1694mm
#
#    height wheel_base kerb_weight     gear_box drive_type steering_type  \
# 0    1642       2500        1465  7-Speed DCT        FWD      Electric
# 1  1800mm     2350mm       943kg      5 Speed        RWD        Manual
# 2    1572       2500        1014      5 Speed       None    Electronic
# 3  1550mm     2380mm       860kg      5 Speed        FWD         Power
# 4  1544mm     2530mm      1042kg      5 Speed        FWD         Power
#
#   seating_capacity front_brake_type rear_brake_type         tyre_type  \
# 0                5             Disc            Drum  Tubeless, Radial
# 1                7  Ventilated Disc            Drum    Tubeless Tyres
# 2                5             Disc            Drum   Tubeless,Radial
# 3                5  Ventilated Disc            Drum          Tubeless
# 4                5             Disc            Drum   Tubeless,Radial
#
#   alloy_wheel_size no_of_doors cargo_volumn     city
# 0               16           5          392  Chennai
# 1             None           5   540-liters  Chennai
# 2               16           5          336  Chennai
# 3             None           5   225-litres  Chennai
# 4               15           5   354-litres  Chennai

# %%
# no of rows and columns
final_df.shape
# Out:
# (8369, 64)

# %%
# saving final df as df
df = final_df

# %%
# converting all lets to lower case

df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df.head()
# Out:
#    ignition_type fuel_type  body_type kilometers_driven transmission  \
# 0              0    petrol        suv            20,000    automatic
# 1              0    petrol   minivans            20,687       manual
# 2              0    petrol        suv            30,000       manual
# 3              0    petrol  hatchback            59,247       manual
# 4              0    petrol  hatchback            50,000       manual
#
#    owner_no      owner manufacturer           model  model_year  \
# 0         1  1st owner          kia       kia sonet        2022
# 1         1  1st owner       maruti     maruti eeco        2015
# 2         1  1st owner       nissan  nissan magnite        2021
# 3         1  1st owner      hyundai     hyundai i10        2015
# 4         1  1st owner        honda      honda jazz        2015
#
#    central_variant_id                   variant_name         price  \
# 0                8654  turbo dct anniversary edition  ₹ 11.50 lakh
# 1                4025         7 seater standard bsiv   ₹ 4.15 lakh
# 2                8135          turbo xv premium bsvi   ₹ 7.50 lakh
# 3                1579                    sportz 1.1l   ₹ 3.98 lakh
# 4                1341                  1.2 vx i vtec   ₹ 5.50 lakh
#
#   priceActual priceSaving priceFixedText  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
#
#                                         trendingText heading description  \
# 0  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 2  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 3  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
# 4  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None        None
#
#   registration_year              insurance Fuel_type  kms_driven   rto  \
# 0              2022  third party insurance    petrol  20,000 kms  tn02
# 1          feb 2015          comprehensive    petrol  20,687 kms  tn04
# 2              2021  third party insurance    petrol  30,000 kms  tn22
# 3          may 2015          comprehensive    petrol  59,247 kms  tn11
# 4              2015  third party insurance    petrol  50,000 kms  ka03
#
#      ownership engine_displacement Transmission  year_of_manufacture  \
# 0  first owner              998 cc    automatic               2022.0
# 1  first owner             1196 cc       manual               2015.0
# 2  first owner              999 cc       manual               2021.0
# 3  first owner             1086 cc       manual               2015.0
# 4  first owner             1199 cc       manual               2015.0
#
#                                          top_eatures  \
# 0  power steering, power windows front, air condi...
# 1  low fuel warning light, accessory power outlet...
# 2  power steering, power windows front, air condi...
# 3  power steering, power windows front, air condi...
# 4  power steering, power windows front, air condi...
#
#                                     comfort_features  \
# 0  power steering, power windows front, power win...
# 1  low fuel warning light, accessory power outlet...
# 2  power steering, power windows front, power win...
# 3  power steering, power windows front, power win...
# 4  power steering, power windows front, power win...
#
#                                    interior_features  \
# 0  air conditioner, heater, adjustable steering, ...
# 1  heater, digital odometer, electronic multi tri...
# 2  air conditioner, heater, adjustable steering, ...
# 3  air conditioner, heater, adjustable steering, ...
# 4  air conditioner, heater, adjustable steering, ...
#
#                                    exterior_features  \
# 0  adjustable head lights, fog lights front, powe...
# 1  adjustable head lights, manually adjustable ex...
# 2  adjustable head lights, fog lights front, powe...
# 3  adjustable head lights, fog lights front, manu...
# 4  adjustable head lights, fog lights front, powe...
#
#                                      safety_features  \
# 0  anti lock braking system, brake assist, center...
# 1  anti lock braking system, child safety locks, ...
# 2  anti lock braking system, brake assist, center...
# 3  centeral locking, power door locks, child safe...
# 4  anti lock braking system, centeral locking, po...
#
#                               entertainment_features   engine  max_power  \
# 0  radio, speakers front, speakers rear, integrat...   998 cc  118.36bhp
# 1                                                     1196 cc      73bhp
# 2  radio, speakers front, speakers rear, integrat...   999 cc   98.63bhp
# 3  cd player, radio, speakers front, speakers rea...  1086 cc   68.05bhp
# 4  cd player, dvd player, radio, speakers front, ...  1199 cc    88.7bhp
#
#     torque wheel_size seats   color               engine_type displacement  \
# 0    172nm         16     5   black  smartstream g1.0 t - gdi          998
# 1    101nm       None     7    grey            in-line engine         1196
# 2    160nm         16     5  others     hra0 1.0 turbo petrol          999
# 3  99.04nm       None     5  silver              irde2 engine         1086
# 4    110nm         15     5  others      i-vtec petrol engine         1199
#
#     engine_max_power   engine_max_torque  no_of_cylinders  \
# 0  118.36bhp@6000rpm  172nm@1500-4000rpm              3.0
# 1      73bhp@6000rpm       101nm@3000rpm              4.0
# 2   98.63bhp@5000rpm  160nm@2800-3600rpm              3.0
# 3   68.05bhp@5500rpm     99.04nm@4500rpm              4.0
# 4    88.7bhp@6000rpm       110nm@4800rpm              4.0
#
#    values_per_cylinder fuel_suppy_system turbo_charger  length   width  \
# 0                  4.0               gdi           yes  3995mm    1790
# 1                  4.0              mpfi            no  3675mm  1475mm
# 2                  4.0              mpfi           yes  3994mm    1758
# 3                  3.0              mpfi            no  3585mm  1595mm
# 4                  4.0          pgm - fi            no  3955mm  1694mm
#
#    height wheel_base kerb_weight     gear_box drive_type steering_type  \
# 0    1642       2500        1465  7-speed dct        fwd      electric
# 1  1800mm     2350mm       943kg      5 speed        rwd        manual
# 2    1572       2500        1014      5 speed       None    electronic
# 3  1550mm     2380mm       860kg      5 speed        fwd         power
# 4  1544mm     2530mm      1042kg      5 speed        fwd         power
#
#   seating_capacity front_brake_type rear_brake_type         tyre_type  \
# 0                5             disc            drum  tubeless, radial
# 1                7  ventilated disc            drum    tubeless tyres
# 2                5             disc            drum   tubeless,radial
# 3                5  ventilated disc            drum          tubeless
# 4                5             disc            drum   tubeless,radial
#
#   alloy_wheel_size no_of_doors cargo_volumn     city
# 0               16           5          392  chennai
# 1             None           5   540-liters  chennai
# 2               16           5          336  chennai
# 3             None           5   225-litres  chennai
# 4               15           5   354-litres  chennai

# %%
#Function to remove manufacturer name from the model

def remove_manufacturer_from_model(row):
    manufacturer = row['manufacturer']
    model = row['model']
    
    # Replace the manufacturer name in the model column with an empty string
    return model.replace(manufacturer, '').strip()

# %%
# Creating seperate column for manufacturer

df['model'] = df.apply(remove_manufacturer_from_model, axis=1)
df[['manufacturer','model']].head(5)
# Out:
#   manufacturer    model
# 0          kia    sonet
# 1       maruti     eeco
# 2       nissan  magnite
# 3      hyundai      i10
# 4        honda     jazz

# %%
df['manufacturer'].unique()
# Out:
# array(['kia', 'maruti', 'nissan', 'hyundai', 'honda', 'mercedes-benz',
#        'bmw', 'ford', 'tata', 'jeep', 'toyota', 'audi', 'mahindra',
#        'renault', 'chevrolet', 'volkswagen', 'datsun', 'fiat',
#        'land rover', 'mg', 'skoda', 'isuzu', 'mini', 'volvo', 'jaguar',
#        'citroen', 'mitsubishi', 'mahindra renault', 'mahindra ssangyong',
#        'lexus', 'hindustan motors', 'opel', 'porsche'], dtype=object)

# %%
# there are some prices in crores so creating a function to conert into lakhs and removing strings like 'Lakh' and 'Crore'

def convert_price_to_lakh(price_str):
    if 'lakh' in price_str:
        # Remove 'Lakh' and convert to float
        return float(price_str.replace('₹', '').replace('lakh', '').strip())
    elif 'crore' in price_str:
        # Remove 'Crore', convert to float, and multiply by 100 to get Lakh
        return float(price_str.replace('₹', '').replace('crore', '').strip()) * 100
    else:
         return None

# %%
df['price'] = df['price'].apply(convert_price_to_lakh)
df['price'].head()
# Out:
# 0    11.50
# 1     4.15
# 2     7.50
# 3     3.98
# 4     5.50
# Name: price, dtype: float64

# %%
#removing , from all columns

df = df.replace(',', '', regex=True)
df.head()
# Out:
#    ignition_type fuel_type  body_type kilometers_driven transmission  \
# 0              0    petrol        suv             20000    automatic
# 1              0    petrol   minivans             20687       manual
# 2              0    petrol        suv             30000       manual
# 3              0    petrol  hatchback             59247       manual
# 4              0    petrol  hatchback             50000       manual
#
#    owner_no      owner manufacturer    model  model_year  central_variant_id  \
# 0         1  1st owner          kia    sonet        2022                8654
# 1         1  1st owner       maruti     eeco        2015                4025
# 2         1  1st owner       nissan  magnite        2021                8135
# 3         1  1st owner      hyundai      i10        2015                1579
# 4         1  1st owner        honda     jazz        2015                1341
#
#                     variant_name  price priceActual priceSaving  \
# 0  turbo dct anniversary edition  11.50
# 1         7 seater standard bsiv   4.15
# 2          turbo xv premium bsvi   7.50
# 3                    sportz 1.1l   3.98
# 4                  1.2 vx i vtec   5.50
#
#   priceFixedText                                       trendingText heading  \
# 0           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 1           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 2           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 3           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 4           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
#
#   description registration_year              insurance Fuel_type kms_driven  \
# 0        None              2022  third party insurance    petrol  20000 kms
# 1        None          feb 2015          comprehensive    petrol  20687 kms
# 2        None              2021  third party insurance    petrol  30000 kms
# 3        None          may 2015          comprehensive    petrol  59247 kms
# 4        None              2015  third party insurance    petrol  50000 kms
#
#     rto    ownership engine_displacement Transmission  year_of_manufacture  \
# 0  tn02  first owner              998 cc    automatic               2022.0
# 1  tn04  first owner             1196 cc       manual               2015.0
# 2  tn22  first owner              999 cc       manual               2021.0
# 3  tn11  first owner             1086 cc       manual               2015.0
# 4  ka03  first owner             1199 cc       manual               2015.0
#
#                                          top_eatures  \
# 0  power steering power windows front air conditi...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front air conditi...
# 3  power steering power windows front air conditi...
# 4  power steering power windows front air conditi...
#
#                                     comfort_features  \
# 0  power steering power windows front power windo...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front power windo...
# 3  power steering power windows front power windo...
# 4  power steering power windows front power windo...
#
#                                    interior_features  \
# 0  air conditioner heater adjustable steering dig...
# 1  heater digital odometer electronic multi tripm...
# 2  air conditioner heater adjustable steering dig...
# 3  air conditioner heater adjustable steering dig...
# 4  air conditioner heater adjustable steering dig...
#
#                                    exterior_features  \
# 0  adjustable head lights fog lights front power ...
# 1  adjustable head lights manually adjustable ext...
# 2  adjustable head lights fog lights front power ...
# 3  adjustable head lights fog lights front manual...
# 4  adjustable head lights fog lights front power ...
#
#                                      safety_features  \
# 0  anti lock braking system brake assist centeral...
# 1  anti lock braking system child safety locks dr...
# 2  anti lock braking system brake assist centeral...
# 3  centeral locking power door locks child safety...
# 4  anti lock braking system centeral locking powe...
#
#                               entertainment_features   engine  max_power  \
# 0  radio speakers front speakers rear integrated2...   998 cc  118.36bhp
# 1                                                     1196 cc      73bhp
# 2  radio speakers front speakers rear integrated2...   999 cc   98.63bhp
# 3  cd player radio speakers front speakers rear i...  1086 cc   68.05bhp
# 4  cd player dvd player radio speakers front spea...  1199 cc    88.7bhp
#
#     torque wheel_size seats   color               engine_type displacement  \
# 0    172nm         16     5   black  smartstream g1.0 t - gdi          998
# 1    101nm       None     7    grey            in-line engine         1196
# 2    160nm         16     5  others     hra0 1.0 turbo petrol          999
# 3  99.04nm       None     5  silver              irde2 engine         1086
# 4    110nm         15     5  others      i-vtec petrol engine         1199
#
#     engine_max_power   engine_max_torque  no_of_cylinders  \
# 0  118.36bhp@6000rpm  172nm@1500-4000rpm              3.0
# 1      73bhp@6000rpm       101nm@3000rpm              4.0
# 2   98.63bhp@5000rpm  160nm@2800-3600rpm              3.0
# 3   68.05bhp@5500rpm     99.04nm@4500rpm              4.0
# 4    88.7bhp@6000rpm       110nm@4800rpm              4.0
#
#    values_per_cylinder fuel_suppy_system turbo_charger  length   width  \
# 0                  4.0               gdi           yes  3995mm    1790
# 1                  4.0              mpfi            no  3675mm  1475mm
# 2                  4.0              mpfi           yes  3994mm    1758
# 3                  3.0              mpfi            no  3585mm  1595mm
# 4                  4.0          pgm - fi            no  3955mm  1694mm
#
#    height wheel_base kerb_weight     gear_box drive_type steering_type  \
# 0    1642       2500        1465  7-speed dct        fwd      electric
# 1  1800mm     2350mm       943kg      5 speed        rwd        manual
# 2    1572       2500        1014      5 speed       None    electronic
# 3  1550mm     2380mm       860kg      5 speed        fwd         power
# 4  1544mm     2530mm      1042kg      5 speed        fwd         power
#
#   seating_capacity front_brake_type rear_brake_type        tyre_type  \
# 0                5             disc            drum  tubeless radial
# 1                7  ventilated disc            drum   tubeless tyres
# 2                5             disc            drum   tubelessradial
# 3                5  ventilated disc            drum         tubeless
# 4                5             disc            drum   tubelessradial
#
#   alloy_wheel_size no_of_doors cargo_volumn     city
# 0               16           5          392  chennai
# 1             None           5   540-liters  chennai
# 2               16           5          336  chennai
# 3             None           5   225-litres  chennai
# 4               15           5   354-litres  chennai

# %%
# Extracting numeric part from strings

def extract_numeric(value):
    if isinstance(value, str):  # Check if the value is a string
        match = re.search(r'\d+\.?\d*', value)  # Use regex to find the first numeric value
        if match:
            return float(match.group())  # Return the numeric part as a float
    return None  # Return None if no match is found

# %%
# List of columns to apply the function to
columns = ['kilometers_driven','kms_driven','engine_displacement','engine','max_power',
                    'torque','wheel_size','seats','length','width', 'height','wheel_base', 'kerb_weight', 'cargo_volumn',
                    'displacement','engine_max_power','engine_max_torque','gear_box','seating_capacity','alloy_wheel_size',
                   'no_of_doors']

# Applying the extract_numeric function to all specified columns
df[columns] = df[columns].applymap(extract_numeric)

# Checking the cleaned data
df[columns].head()
# Out:
#    kilometers_driven  kms_driven  engine_displacement  engine  max_power  \
# 0            20000.0     20000.0                998.0   998.0     118.36
# 1            20687.0     20687.0               1196.0  1196.0      73.00
# 2            30000.0     30000.0                999.0   999.0      98.63
# 3            59247.0     59247.0               1086.0  1086.0      68.05
# 4            50000.0     50000.0               1199.0  1199.0      88.70
#
#    torque  wheel_size  seats  length   width  height  wheel_base  kerb_weight  \
# 0  172.00        16.0    5.0  3995.0  1790.0  1642.0      2500.0       1465.0
# 1  101.00         NaN    7.0  3675.0  1475.0  1800.0      2350.0        943.0
# 2  160.00        16.0    5.0  3994.0  1758.0  1572.0      2500.0       1014.0
# 3   99.04         NaN    5.0  3585.0  1595.0  1550.0      2380.0        860.0
# 4  110.00        15.0    5.0  3955.0  1694.0  1544.0      2530.0       1042.0
#
#    cargo_volumn  displacement  engine_max_power  engine_max_torque  gear_box  \
# 0         392.0         998.0            118.36             172.00       7.0
# 1         540.0        1196.0             73.00             101.00       5.0
# 2         336.0         999.0             98.63             160.00       5.0
# 3         225.0        1086.0             68.05              99.04       5.0
# 4         354.0        1199.0             88.70             110.00       5.0
#
#    seating_capacity  alloy_wheel_size  no_of_doors
# 0               5.0              16.0          5.0
# 1               7.0               NaN          5.0
# 2               5.0              16.0          5.0
# 3               5.0               NaN          5.0
# 4               5.0              15.0          5.0

# %%
# extracting only year from registration year 

df['registration_year'] = df['registration_year'].str[-4:].astype(float)

# %%
df.head(5)
# Out:
#    ignition_type fuel_type  body_type  kilometers_driven transmission  \
# 0              0    petrol        suv            20000.0    automatic
# 1              0    petrol   minivans            20687.0       manual
# 2              0    petrol        suv            30000.0       manual
# 3              0    petrol  hatchback            59247.0       manual
# 4              0    petrol  hatchback            50000.0       manual
#
#    owner_no      owner manufacturer    model  model_year  central_variant_id  \
# 0         1  1st owner          kia    sonet        2022                8654
# 1         1  1st owner       maruti     eeco        2015                4025
# 2         1  1st owner       nissan  magnite        2021                8135
# 3         1  1st owner      hyundai      i10        2015                1579
# 4         1  1st owner        honda     jazz        2015                1341
#
#                     variant_name  price priceActual priceSaving  \
# 0  turbo dct anniversary edition  11.50
# 1         7 seater standard bsiv   4.15
# 2          turbo xv premium bsvi   7.50
# 3                    sportz 1.1l   3.98
# 4                  1.2 vx i vtec   5.50
#
#   priceFixedText                                       trendingText heading  \
# 0           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 1           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 2           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 3           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
# 4           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...    None
#
#   description  registration_year              insurance Fuel_type  kms_driven  \
# 0        None             2022.0  third party insurance    petrol     20000.0
# 1        None             2015.0          comprehensive    petrol     20687.0
# 2        None             2021.0  third party insurance    petrol     30000.0
# 3        None             2015.0          comprehensive    petrol     59247.0
# 4        None             2015.0  third party insurance    petrol     50000.0
#
#     rto    ownership  engine_displacement Transmission  year_of_manufacture  \
# 0  tn02  first owner                998.0    automatic               2022.0
# 1  tn04  first owner               1196.0       manual               2015.0
# 2  tn22  first owner                999.0       manual               2021.0
# 3  tn11  first owner               1086.0       manual               2015.0
# 4  ka03  first owner               1199.0       manual               2015.0
#
#                                          top_eatures  \
# 0  power steering power windows front air conditi...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front air conditi...
# 3  power steering power windows front air conditi...
# 4  power steering power windows front air conditi...
#
#                                     comfort_features  \
# 0  power steering power windows front power windo...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front power windo...
# 3  power steering power windows front power windo...
# 4  power steering power windows front power windo...
#
#                                    interior_features  \
# 0  air conditioner heater adjustable steering dig...
# 1  heater digital odometer electronic multi tripm...
# 2  air conditioner heater adjustable steering dig...
# 3  air conditioner heater adjustable steering dig...
# 4  air conditioner heater adjustable steering dig...
#
#                                    exterior_features  \
# 0  adjustable head lights fog lights front power ...
# 1  adjustable head lights manually adjustable ext...
# 2  adjustable head lights fog lights front power ...
# 3  adjustable head lights fog lights front manual...
# 4  adjustable head lights fog lights front power ...
#
#                                      safety_features  \
# 0  anti lock braking system brake assist centeral...
# 1  anti lock braking system child safety locks dr...
# 2  anti lock braking system brake assist centeral...
# 3  centeral locking power door locks child safety...
# 4  anti lock braking system centeral locking powe...
#
#                               entertainment_features  engine  max_power  \
# 0  radio speakers front speakers rear integrated2...   998.0     118.36
# 1                                                     1196.0      73.00
# 2  radio speakers front speakers rear integrated2...   999.0      98.63
# 3  cd player radio speakers front speakers rear i...  1086.0      68.05
# 4  cd player dvd player radio speakers front spea...  1199.0      88.70
#
#    torque  wheel_size  seats   color               engine_type  displacement  \
# 0  172.00        16.0    5.0   black  smartstream g1.0 t - gdi         998.0
# 1  101.00         NaN    7.0    grey            in-line engine        1196.0
# 2  160.00        16.0    5.0  others     hra0 1.0 turbo petrol         999.0
# 3   99.04         NaN    5.0  silver              irde2 engine        1086.0
# 4  110.00        15.0    5.0  others      i-vtec petrol engine        1199.0
#
#    engine_max_power  engine_max_torque  no_of_cylinders  values_per_cylinder  \
# 0            118.36             172.00              3.0                  4.0
# 1             73.00             101.00              4.0                  4.0
# 2             98.63             160.00              3.0                  4.0
# 3             68.05              99.04              4.0                  3.0
# 4             88.70             110.00              4.0                  4.0
#
#   fuel_suppy_system turbo_charger  length   width  height  wheel_base  \
# 0               gdi           yes  3995.0  1790.0  1642.0      2500.0
# 1              mpfi            no  3675.0  1475.0  1800.0      2350.0
# 2              mpfi           yes  3994.0  1758.0  1572.0      2500.0
# 3              mpfi            no  3585.0  1595.0  1550.0      2380.0
# 4          pgm - fi            no  3955.0  1694.0  1544.0      2530.0
#
#    kerb_weight  gear_box drive_type steering_type  seating_capacity  \
# 0       1465.0       7.0        fwd      electric               5.0
# 1        943.0       5.0        rwd        manual               7.0
# 2       1014.0       5.0       None    electronic               5.0
# 3        860.0       5.0        fwd         power               5.0
# 4       1042.0       5.0        fwd         power               5.0
#
#   front_brake_type rear_brake_type        tyre_type  alloy_wheel_size  \
# 0             disc            drum  tubeless radial              16.0
# 1  ventilated disc            drum   tubeless tyres               NaN
# 2             disc            drum   tubelessradial              16.0
# 3  ventilated disc            drum         tubeless               NaN
# 4             disc            drum   tubelessradial              15.0
#
#    no_of_doors  cargo_volumn     city
# 0          5.0         392.0  chennai
# 1          5.0         540.0  chennai
# 2          5.0         336.0  chennai
# 3          5.0         225.0  chennai
# 4          5.0         354.0  chennai

# %%
# checking data types 

df.dtypes
# Out:
# ignition_type               int64
# fuel_type                  object
# body_type                  object
# kilometers_driven         float64
# transmission               object
# owner_no                    int64
# owner                      object
# manufacturer               object
# model                      object
# model_year                  int64
# central_variant_id          int64
# variant_name               object
# price                     float64
# priceActual                object
# priceSaving                object
# priceFixedText             object
# trendingText               object
# heading                    object
# description                object
# registration_year         float64
# insurance                  object
# Fuel_type                  object
# kms_driven                float64
# rto                        object
# ownership                  object
# engine_displacement       float64
# Transmission               object
# year_of_manufacture       float64
# top_eatures                object
# comfort_features           object
# interior_features          object
# exterior_features          object
# safety_features            object
# entertainment_features     object
# engine                    float64
# max_power                 float64
# torque                    float64
# wheel_size                float64
# seats                     float64
# color                      object
# engine_type                object
# displacement              float64
# engine_max_power          float64
# engine_max_torque         float64
# no_of_cylinders           float64
# values_per_cylinder       float64
# fuel_suppy_system          object
# turbo_charger              object
# length                    float64
# width                     float64
# height                    float64
# wheel_base                float64
# kerb_weight               float64
# gear_box                  float64
# drive_type                 object
# steering_type              object
# seating_capacity          float64
# front_brake_type           object
# rear_brake_type            object
# tyre_type                  object
# alloy_wheel_size          float64
# no_of_doors               float64
# cargo_volumn              float64
# city                       object
# dtype: object

# %%
# checking null values

df.isna().sum()
# Out:
# ignition_type                0
# fuel_type                    0
# body_type                    0
# kilometers_driven            0
# transmission                 0
# owner_no                     0
# owner                        0
# manufacturer                 0
# model                        0
# model_year                   0
# central_variant_id           0
# variant_name                 0
# price                      110
# priceActual                  0
# priceSaving                  0
# priceFixedText            8369
# trendingText                 0
# heading                   8369
# description               8369
# registration_year           52
# insurance                    4
# Fuel_type                    0
# kms_driven                   2
# rto                        888
# ownership                   32
# engine_displacement          4
# Transmission                 0
# year_of_manufacture         20
# top_eatures                  0
# comfort_features             0
# interior_features            0
# exterior_features            0
# safety_features              0
# entertainment_features       0
# engine                       4
# max_power                   60
# torque                      60
# wheel_size                2983
# seats                        6
# color                        3
# engine_type                295
# displacement                 4
# engine_max_power            60
# engine_max_torque           60
# no_of_cylinders             31
# values_per_cylinder         51
# fuel_suppy_system         1727
# turbo_charger             1040
# length                      79
# width                       83
# height                      79
# wheel_base                 163
# kerb_weight                 60
# gear_box                   326
# drive_type                1560
# steering_type              255
# seating_capacity             6
# front_brake_type            96
# rear_brake_type             96
# tyre_type                   77
# alloy_wheel_size          2983
# no_of_doors                 11
# cargo_volumn              1593
# city                         0
# dtype: int64

# %%
# cheking the uique values in categorical columns

columns = ['body_type','insurance','ownership','fuel_suppy_system','turbo_charger','drive_type','steering_type',
           'front_brake_type','rear_brake_type','tyre_type']



for col in columns:
    print(f"Value counts for '{col}':")
    
    # Print the number of unique values in each column
    unique_count = df[col].nunique()  # Count unique values
    print(f"Number of unique values: {unique_count}")

    
    # Print the value counts for each unique value
    print(f"Value counts in '{col}':\n{df[col].value_counts()}")
    print("-" * 50)  # Separator for readability
# Out:
# Value counts for 'body_type':
# Number of unique values: 11
# Value counts in 'body_type':
# body_type
# hatchback        3567
# suv              2225
# sedan            2174
# muv               352
# minivans           23
# coupe              10
# pickup trucks       6
# convertibles        6
#                     4
# hybrids             1
# wagon               1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'insurance':
# Number of unique values: 7
# Value counts in 'insurance':
# insurance
# third party insurance    4055
# comprehensive            3150
# third party               630
# zero dep                  303
# not available             223
# 1                           3
# 2                           1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'ownership':
# Number of unique values: 5
# Value counts in 'ownership':
# ownership
# first owner     5882
# second owner    1982
# third owner      374
# fourth owner      80
# fifth owner       19
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'fuel_suppy_system':
# Number of unique values: 67
# Value counts in 'fuel_suppy_system':
# fuel_suppy_system
# mpfi                                  2918
# crdi                                  1725
# direct injection                       729
# pgm-fi                                 215
# pgm - fi                               157
# gdi                                    119
# mpi                                     87
# common rail                             79
# efi                                     73
# efi(electronic fuel injection)          62
# tsi                                     60
# sefi                                    44
# pgm-fi (programmed fuel injection)      39
# mpfi                                    34
# efi (electronic fuel injection)         29
# direct injection                        29
# tdci                                    27
# cdi                                     19
# electronic injection system             15
# electronic fuel injection               13
# common-rail type                        12
# multi-point injection                   11
# common rail direct injection            10
# multi point fuel injection              10
# multipoint injection                     9
# mpfi+lpg                                 9
# ddis                                     7
# indirect injection                       6
# direct injection common rail             6
# intelligent-gas port injection           6
# gasoline direct injection                5
# common rail                              5
# pfi                                      4
# common rail direct injection (dci)       4
# dpfi                                     4
# egis                                     4
# efic                                     4
# pgm-fi (programmed fuel inje             4
# electronic fuel injection(efi)           4
# tgdi                                     3
# advanced common rail                     3
# isg                                      3
# tfsi                                     2
# cng                                      2
# d-4s                                     2
# crdi                                     2
# dedst                                    2
# smpi                                     2
# electric                                 2
# common rail diesel                       2
# mpfi+cng                                 2
# common rail injection                    2
# 3 phase ac induction motors              2
# direct injectio                          1
# vvt-ie                                   1
# tdi                                      1
# pgm-fi (programmed fuel inject           1
# direct fuel injection                    1
# common rail system                       1
# dual vvt-i                               1
# direct injection common rail             1
# dohc                                     1
# mfi                                      1
# distribution type fuel injection         1
# idi                                      1
# ti-vct                                   1
# efi (electronic fuel injection           1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'turbo_charger':
# Number of unique values: 4
# Value counts in 'turbo_charger':
# turbo_charger
# no       4260
# yes      3014
# twin       53
# turbo       2
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'drive_type':
# Number of unique values: 18
# Value counts in 'drive_type':
# drive_type
# fwd                                  5509
# rwd                                   416
# awd                                   282
# 2wd                                   159
# 4wd                                   143
# 4x2                                    86
# 4x4                                    52
# 2 wd                                   47
# front wheel drive                      43
# fwd                                    34
# two wheel drive                        15
# all wheel drive                         7
# rear wheel drive with esp               6
# rwd(with mtt)                           5
# permanent all-wheel drive quattro       2
# 2wd                                     1
# awd integrated management               1
# 4 wd                                    1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'steering_type':
# Number of unique values: 7
# Value counts in 'steering_type':
# steering_type
# power         6423
# electric      1440
# electronic     106
# manual          86
# electrical      48
# epas             9
# hydraulic        2
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'front_brake_type':
# Number of unique values: 27
# Value counts in 'front_brake_type':
# front_brake_type
# disc                                        5321
# ventilated disc                             2575
# ventilated discs                              77
# disc                                          73
# solid disc                                    64
# disc & caliper type                           42
# ventilated disc                               26
# disk                                          23
# ventilated disk                               11
# vantilated disc                                8
# disc 236 mm                                    8
#  disc                                          6
# ventlated disc                                 6
# drum                                           6
# multilateral disc                              6
# electric parking brake                         3
# ventillated disc                               3
# caliper ventilated disc                        2
# booster assisted ventilated disc               2
#  ventilated disc                               2
# vacuum assisted hydraulic dual circuit w       2
# mechanical-hydraulic dual circuit              2
# abs                                            1
# discinternally ventilated                      1
# discs                                          1
# tandem master cylinder with servo assist       1
# disc brakes                                    1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'rear_brake_type':
# Number of unique values: 29
# Value counts in 'rear_brake_type':
# rear_brake_type
# drum                                        6445
# disc                                        1197
# ventilated disc                              196
# solid disc                                   124
# discs                                         85
# disc & caliper type                           42
# ventilated discs                              34
# leading-trailing drum                         30
# self-adjusting drum                           25
# leading & trailing drum                       16
# self adjusting drums                           9
# drums                                          9
# drums 180 mm                                   8
# disc & drum                                    7
# ventilated disc                                6
# drum                                           6
# solid disc                                     5
# ventilated drum                                4
# drum`                                          3
# electric parking brake                         3
# disc                                           3
# drum in discs                                  3
# ventialte disc                                 2
# self adjusting drum                            2
# booster assisted drum                          2
# vacuum assisted hydraulic dual circuit w       2
# mechanical-hydraulic dual circuit              2
# drum in disc                                   2
# 228.6 mm dia drums on rear wheels              1
# Name: count, dtype: int64
# --------------------------------------------------
# Value counts for 'tyre_type':
# Number of unique values: 31
# Value counts in 'tyre_type':
# tyre_type
# tubelessradial                4436
# tubeless radial               1410
# tubeless                      1167
# tubeless tyres                 423
# radial tubeless                232
# radial                         134
# radial tubless                  82
# tubeless tyres radial           61
# tubelessradial                  57
# radialtubeless                  55
# tubeless radial tyres           53
# tubelessradials                 33
# tubless radial                  29
# tubelessrunflat                 18
# tubeless runflat                17
# tubeless tyre                   16
# run-flat                        14
# runflat                         12
# runflat tyres                   11
# tubeless                         7
# runflat tyre                     5
# radial                           5
# tubeless tyres mud terrain       3
# tubeless radials tyre            3
# radial with tube                 2
# tubeless. runflat                2
# tublessradial                    1
# runflatradial                    1
# tubeless tyres all terrain       1
# radial tyres                     1
# tubeless radials                 1
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# ### There are repeated values but due to spacing and improper data entry they are categorised differently so replacing them

# %%
# Function to normalize column values and replace with dictionary
def normalize_and_replace(df, column, replace_dict):
    # Normalize spaces and lowercase the column
    df[column] = df[column].str.strip().str.lower()
    
    # Apply replacements from the dictionary
    for standard_value, variations in replace_dict.items():
        df[column].replace(variations, standard_value, inplace=True)
    
    # Return the updated dataframe
    return df

# %%
# Dictionary for 'fuel_suppy_system' replacements
body_type_replace = {'unknown': ['']}

insurance_replace = {'third party': ['third party insurance']}

fuel_system_replace = {
    'pgm-fi': ['pgm - fi', 'pgm-fi (programmed fuel injection)', 'pgm-fi (programmed fuel inje', 'pgm-fi (programmed fuel inject'],
    'efi': ['efi (electronic fuel injection)', 'efi(electronic fuel injection)', 'electronic injection system', 'electronic fuel injection', 'electronic fuel injection(efi)', 'efi (electronic fuel injection', 'efic'],
    'mpfi': ['mpfi ', 'mfi ', 'multi point fuel injection'],
    'mpi': ['multi-point injection', 'multipoint injection'],
    'crdi': ['crdi ', 'common rail direct injection (dci)', 'common rail direct injection', 'direct injection common rail ', 'direct injection common rail'],
    'common-rail': ['common rail', 'common rail ', 'common rail diesel', 'common rail injection', 'common rail system', 'common-rail type'],
    'direct injection': ['direct injectio', 'direct fuel injection', 'direct injection ', 'direct injection common rail'],
}

# Dictionary for 'drive_type' replacements
drive_type_replace = {
    '2wd': ['2 wd', 'two wheel drive', '4x2'],
    'fwd': ['front wheel drive'],
    'awd': ['all wheel drive'],
    '4wd': ['4 wd', '4x4'],
}

# Dictionary for 'steering_type' replacements
steering_type_replace = {
    'electric': ['electronic', 'electrical']
}


# Dictionary for 'front_brake_type' replacements
front_brake_type_replace = {
    'ventilated disc': ['ventilated discs','ventilated disk','ventlated disc','ventillated disc',' ventilated disc',
                       'caliper ventilated disc','booster assisted ventilated disc','discinternally ventilated','vantilated disc'],
    'disc': ['disk',' disc','disc brakes','discs','disc brakes','disc 236 mm']    
}


# Dictionary for 'rear_brake_type' replacements
rear_brake_type_replace = {
    'ventilated disc': ['ventilated discs','ventilated disc ','ventialte disc'],
    'disc': ['discs',' disc'],
    'drum': ['drums','drums 180 mm','drum ','drum`','drums 180 mm','228.6 mm dia drums on rear wheels'],
    'self-adjusting drum': ['self adjusting drums'], 
    'leading-trailing drum': ['leading & trailing drum'],
    'disc & drum': ['drum in disc','drum in discs'],   
}


# Dictionary for 'tyre_type_replace' replacements
tyre_type_replace = {
    'tubeless radial': ['tubelessradial','radial tubeless','radial tubless','tubeless tyres radial','tubelessradial','radialtubeless',
                       'tubeless radial tyres','tubelessradials','tubless radial','tublessradial','tubeless radials','tubeless radials tyre',
                       ],
    'tubeless runflat': ['tubelessrunflat','tubeless. runflat','tubeless. runflat','tubeless runflat' ],
    'run-flat': ['runflat',' runflat tyres','runflat tyre','runflatradial','radial with tube','runflat tyres'],
    'tubeless': ['tubeless','tubeless tyres','tubeless tyre','tubeless tyres mud terrain','tubeless tyres all terrain'], 
    'radial': ['radial','radial tyres'],   
}

# %%
# Apply normalization and replacement for each column
df = normalize_and_replace(df, 'body_type', body_type_replace)
df = normalize_and_replace(df, 'insurance', insurance_replace)
df = normalize_and_replace(df, 'fuel_suppy_system', fuel_system_replace)
df = normalize_and_replace(df, 'drive_type', drive_type_replace)
df = normalize_and_replace(df, 'steering_type', steering_type_replace)
df = normalize_and_replace(df, 'front_brake_type', front_brake_type_replace)
df = normalize_and_replace(df, 'rear_brake_type', rear_brake_type_replace)
df = normalize_and_replace(df, 'tyre_type', tyre_type_replace)


# Verify the changes
print(df['body_type'].value_counts())
print(df['insurance'].value_counts())
print(df['fuel_suppy_system'].value_counts())
print(df['drive_type'].value_counts())
print(df['steering_type'].value_counts())
print(df['front_brake_type'].value_counts())
print(df['rear_brake_type'].value_counts())
print(df['tyre_type'].value_counts())
# Out:
# body_type
# hatchback        3567
# suv              2225
# sedan            2174
# muv               352
# minivans           23
# coupe              10
# pickup trucks       6
# convertibles        6
# unknown             4
# hybrids             1
# wagon               1
# Name: count, dtype: int64
# insurance
# third party      4685
# comprehensive    3150
# zero dep          303
# not available     223
# 1                   3
# 2                   1
# Name: count, dtype: int64
# fuel_suppy_system
# mpfi                                2962
# crdi                                1748
# direct injection                     760
# pgm-fi                               416
# efi                                  201
# gdi                                  119
# mpi                                  107
# common-rail                          101
# tsi                                   60
# sefi                                  44
# tdci                                  27
# cdi                                   19
# mpfi+lpg                               9
# ddis                                   7
# indirect injection                     6
# intelligent-gas port injection         6
# gasoline direct injection              5
# dpfi                                   4
# egis                                   4
# pfi                                    4
# advanced common rail                   3
# isg                                    3
# tgdi                                   3
# d-4s                                   2
# cng                                    2
# dedst                                  2
# mpfi+cng                               2
# 3 phase ac induction motors            2
# smpi                                   2
# electric                               2
# tfsi                                   2
# distribution type fuel injection       1
# dual vvt-i                             1
# ti-vct                                 1
# idi                                    1
# mfi                                    1
# dohc                                   1
# vvt-ie                                 1
# tdi                                    1
# Name: count, dtype: int64
# drive_type
# fwd                                  5586
# rwd                                   416
# 2wd                                   308
# awd                                   289
# 4wd                                   196
# rear wheel drive with esp               6
# rwd(with mtt)                           5
# permanent all-wheel drive quattro       2
# awd integrated management               1
# Name: count, dtype: int64
# steering_type
# power        6423
# electric     1594
# manual         86
# epas            9
# hydraulic       2
# Name: count, dtype: int64
# front_brake_type
# disc                                        5433
# ventilated disc                             2713
# solid disc                                    64
# disc & caliper type                           42
# multilateral disc                              6
# drum                                           6
# electric parking brake                         3
# vacuum assisted hydraulic dual circuit w       2
# mechanical-hydraulic dual circuit              2
# abs                                            1
# tandem master cylinder with servo assist       1
# Name: count, dtype: int64
# rear_brake_type
# drum                                        6472
# disc                                        1285
# ventilated disc                              238
# solid disc                                   129
# leading-trailing drum                         46
# disc & caliper type                           42
# self-adjusting drum                           34
# disc & drum                                   12
# ventilated drum                                4
# electric parking brake                         3
# booster assisted drum                          2
# self adjusting drum                            2
# vacuum assisted hydraulic dual circuit w       2
# mechanical-hydraulic dual circuit              2
# Name: count, dtype: int64
# tyre_type
# tubeless radial     6453
# tubeless            1617
# radial               140
# run-flat              45
# tubeless runflat      37
# Name: count, dtype: int64

# %%
# as price is what we are predicting deleting null values in price 

df.dropna(subset=['price'], inplace=True)

# %%
# these columns have many unique values enconding and using them reduces mode efficiency so dropping them


df = df.drop(['ignition_type','Fuel_type','owner','priceActual','priceSaving','trendingText','kms_driven','ownership',
              'year_of_manufacture','engine_max_power','engine_max_torque','seating_capacity','priceFixedText',
              'heading','description','Transmission','engine_displacement','displacement'],axis =1)

# %%
df.head()
# Out:
#   fuel_type  body_type  kilometers_driven transmission  owner_no manufacturer  \
# 0    petrol        suv            20000.0    automatic         1          kia
# 1    petrol   minivans            20687.0       manual         1       maruti
# 2    petrol        suv            30000.0       manual         1       nissan
# 3    petrol  hatchback            59247.0       manual         1      hyundai
# 4    petrol  hatchback            50000.0       manual         1        honda
#
#      model  model_year  central_variant_id                   variant_name  \
# 0    sonet        2022                8654  turbo dct anniversary edition
# 1     eeco        2015                4025         7 seater standard bsiv
# 2  magnite        2021                8135          turbo xv premium bsvi
# 3      i10        2015                1579                    sportz 1.1l
# 4     jazz        2015                1341                  1.2 vx i vtec
#
#    price  registration_year      insurance   rto  \
# 0  11.50             2022.0    third party  tn02
# 1   4.15             2015.0  comprehensive  tn04
# 2   7.50             2021.0    third party  tn22
# 3   3.98             2015.0  comprehensive  tn11
# 4   5.50             2015.0    third party  ka03
#
#                                          top_eatures  \
# 0  power steering power windows front air conditi...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front air conditi...
# 3  power steering power windows front air conditi...
# 4  power steering power windows front air conditi...
#
#                                     comfort_features  \
# 0  power steering power windows front power windo...
# 1  low fuel warning light accessory power outlet ...
# 2  power steering power windows front power windo...
# 3  power steering power windows front power windo...
# 4  power steering power windows front power windo...
#
#                                    interior_features  \
# 0  air conditioner heater adjustable steering dig...
# 1  heater digital odometer electronic multi tripm...
# 2  air conditioner heater adjustable steering dig...
# 3  air conditioner heater adjustable steering dig...
# 4  air conditioner heater adjustable steering dig...
#
#                                    exterior_features  \
# 0  adjustable head lights fog lights front power ...
# 1  adjustable head lights manually adjustable ext...
# 2  adjustable head lights fog lights front power ...
# 3  adjustable head lights fog lights front manual...
# 4  adjustable head lights fog lights front power ...
#
#                                      safety_features  \
# 0  anti lock braking system brake assist centeral...
# 1  anti lock braking system child safety locks dr...
# 2  anti lock braking system brake assist centeral...
# 3  centeral locking power door locks child safety...
# 4  anti lock braking system centeral locking powe...
#
#                               entertainment_features  engine  max_power  \
# 0  radio speakers front speakers rear integrated2...   998.0     118.36
# 1                                                     1196.0      73.00
# 2  radio speakers front speakers rear integrated2...   999.0      98.63
# 3  cd player radio speakers front speakers rear i...  1086.0      68.05
# 4  cd player dvd player radio speakers front spea...  1199.0      88.70
#
#    torque  wheel_size  seats   color               engine_type  \
# 0  172.00        16.0    5.0   black  smartstream g1.0 t - gdi
# 1  101.00         NaN    7.0    grey            in-line engine
# 2  160.00        16.0    5.0  others     hra0 1.0 turbo petrol
# 3   99.04         NaN    5.0  silver              irde2 engine
# 4  110.00        15.0    5.0  others      i-vtec petrol engine
#
#    no_of_cylinders  values_per_cylinder fuel_suppy_system turbo_charger  \
# 0              3.0                  4.0               gdi           yes
# 1              4.0                  4.0              mpfi            no
# 2              3.0                  4.0              mpfi           yes
# 3              4.0                  3.0              mpfi            no
# 4              4.0                  4.0            pgm-fi            no
#
#    length   width  height  wheel_base  kerb_weight  gear_box drive_type  \
# 0  3995.0  1790.0  1642.0      2500.0       1465.0       7.0        fwd
# 1  3675.0  1475.0  1800.0      2350.0        943.0       5.0        rwd
# 2  3994.0  1758.0  1572.0      2500.0       1014.0       5.0       None
# 3  3585.0  1595.0  1550.0      2380.0        860.0       5.0        fwd
# 4  3955.0  1694.0  1544.0      2530.0       1042.0       5.0        fwd
#
#   steering_type front_brake_type rear_brake_type        tyre_type  \
# 0      electric             disc            drum  tubeless radial
# 1        manual  ventilated disc            drum         tubeless
# 2      electric             disc            drum  tubeless radial
# 3         power  ventilated disc            drum         tubeless
# 4         power             disc            drum  tubeless radial
#
#    alloy_wheel_size  no_of_doors  cargo_volumn     city
# 0              16.0          5.0         392.0  chennai
# 1               NaN          5.0         540.0  chennai
# 2              16.0          5.0         336.0  chennai
# 3               NaN          5.0         225.0  chennai
# 4              15.0          5.0         354.0  chennai

# %%
df.shape
# Out:
# (8259, 46)

# %%
df.isna().sum()
# Out:
# fuel_type                    0
# body_type                    0
# kilometers_driven            0
# transmission                 0
# owner_no                     0
# manufacturer                 0
# model                        0
# model_year                   0
# central_variant_id           0
# variant_name                 0
# price                        0
# registration_year           42
# insurance                    4
# rto                        859
# top_eatures                  0
# comfort_features             0
# interior_features            0
# exterior_features            0
# safety_features              0
# entertainment_features       0
# engine                       4
# max_power                   45
# torque                      45
# wheel_size                2977
# seats                        6
# color                        3
# engine_type                280
# no_of_cylinders             31
# values_per_cylinder         48
# fuel_suppy_system         1706
# turbo_charger             1022
# length                      62
# width                       66
# height                      62
# wheel_base                 146
# kerb_weight                 45
# gear_box                   309
# drive_type                1520
# steering_type              255
# front_brake_type            81
# rear_brake_type             81
# tyre_type                   74
# alloy_wheel_size          2977
# no_of_doors                 11
# cargo_volumn              1518
# city                         0
# dtype: int64

# %% [markdown]
# # Handling Missing Values:

# %%
# If registration year is missing, filling it with the model year

df['registration_year'].fillna(df['model_year'], inplace=True)
df['insurance'].fillna('not available', inplace=True)
df['rto'].fillna('unknown', inplace=True)

# %%
# filling missing values with the mean in numerical columns

columns = ['engine', 'max_power', 'torque','wheel_size','length','width',
           'height','wheel_base','kerb_weight','cargo_volumn','alloy_wheel_size']

# Loop over the columns and fill missing values with the mean
for column in columns:
    df[column].fillna(df[column].mean(), inplace=True)

# Verify the changes
print(df[columns].isnull().sum())
# Out:
# engine              0
# max_power           0
# torque              0
# wheel_size          0
# length              0
# width               0
# height              0
# wheel_base          0
# kerb_weight         0
# cargo_volumn        0
# alloy_wheel_size    0
# dtype: int64

# %%
# filling with mode in categorical columns

columns = ['color', 'engine_type','front_brake_type','rear_brake_type','tyre_type']

# Loop over the columns and fill missing values with the mode
for column in columns:
    df[column].fillna(df[column].mode()[0], inplace=True)

# Verify the changes
print(df[columns].isnull().sum())
# Out:
# color               0
# engine_type         0
# front_brake_type    0
# rear_brake_type     0
# tyre_type           0
# dtype: int64

# %%
# filling with median in categorical columns

columns = ['seats', 'no_of_doors','no_of_cylinders','values_per_cylinder','gear_box']

# Loop over the columns and fill missing values with the median
for column in columns:
    df[column].fillna(df[column].median(), inplace=True)

# Verify the changes
print(df[columns].isnull().sum())
# Out:
# seats                  0
# no_of_doors            0
# no_of_cylinders        0
# values_per_cylinder    0
# gear_box               0
# dtype: int64

# %%
# replacing null values with unknown 

columns = ['fuel_suppy_system','turbo_charger','drive_type','steering_type']


for column in columns:
    df[column].fillna('unknown', inplace=True)

# Verify the changes
print(df[columns].isnull().sum())
# Out:
# fuel_suppy_system    0
# turbo_charger        0
# drive_type           0
# steering_type        0
# dtype: int64

# %%
# checking null values 

df.isna().sum()
# Out:
# fuel_type                 0
# body_type                 0
# kilometers_driven         0
# transmission              0
# owner_no                  0
# manufacturer              0
# model                     0
# model_year                0
# central_variant_id        0
# variant_name              0
# price                     0
# registration_year         0
# insurance                 0
# rto                       0
# top_eatures               0
# comfort_features          0
# interior_features         0
# exterior_features         0
# safety_features           0
# entertainment_features    0
# engine                    0
# max_power                 0
# torque                    0
# wheel_size                0
# seats                     0
# color                     0
# engine_type               0
# no_of_cylinders           0
# values_per_cylinder       0
# fuel_suppy_system         0
# turbo_charger             0
# length                    0
# width                     0
# height                    0
# wheel_base                0
# kerb_weight               0
# gear_box                  0
# drive_type                0
# steering_type             0
# front_brake_type          0
# rear_brake_type           0
# tyre_type                 0
# alloy_wheel_size          0
# no_of_doors               0
# cargo_volumn              0
# city                      0
# dtype: int64

# %%
# checking data types

df.dtypes
# Out:
# fuel_type                  object
# body_type                  object
# kilometers_driven         float64
# transmission               object
# owner_no                    int64
# manufacturer               object
# model                      object
# model_year                  int64
# central_variant_id          int64
# variant_name               object
# price                     float64
# registration_year         float64
# insurance                  object
# rto                        object
# top_eatures                object
# comfort_features           object
# interior_features          object
# exterior_features          object
# safety_features            object
# entertainment_features     object
# engine                    float64
# max_power                 float64
# torque                    float64
# wheel_size                float64
# seats                     float64
# color                      object
# engine_type                object
# no_of_cylinders           float64
# values_per_cylinder       float64
# fuel_suppy_system          object
# turbo_charger              object
# length                    float64
# width                     float64
# height                    float64
# wheel_base                float64
# kerb_weight               float64
# gear_box                  float64
# drive_type                 object
# steering_type              object
# front_brake_type           object
# rear_brake_type            object
# tyre_type                  object
# alloy_wheel_size          float64
# no_of_doors               float64
# cargo_volumn              float64
# city                       object
# dtype: object

# %%
# saving the cleaned data set

df.to_csv('cleaned_data.csv',index=False)
